# %%
import pandas as pd
df=pd.read_csv('/content/archive (2).zip')
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
df.describe(include='O')
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count       145460    145460      135134     134894     141232    142199
# unique        3436        49          16         16         16         2
# top     2013-11-12  Canberra           W          N         SE        No
# freq            49      3436        9915      11758      10838    110319
#
#        RainTomorrow
# count        142193
# unique            2
# top              No
# freq         110316

# %%
df.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df['MinTemp']=df['MinTemp'].fillna(df['MinTemp'].mode()[0])
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
df['MaxTemp']=df['MaxTemp'].fillna(df['MaxTemp'].mode()[0])
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9     20.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
df['Evaporation']=df['Evaporation'].fillna(df['Evaporation'].mode()[0])
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          4.0
# 1       2008-12-02   Albury      7.4     25.1       0.0          4.0
# 2       2008-12-03   Albury     12.9     25.7       0.0          4.0
# 3       2008-12-04   Albury      9.2     28.0       0.0          4.0
# 4       2008-12-05   Albury     17.5     32.3       1.0          4.0
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          4.0
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          4.0
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          4.0
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          4.0
# 145459  2017-06-25    Uluru     14.9     20.0       0.0          4.0
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp              0
# Rainfall          3261
# Evaporation          0
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 1      2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 2      2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 3      2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 4      2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
# ...           ...      ...      ...      ...       ...          ...       ...
# 58295  2017-06-20   Darwin     19.3     33.4       0.0          6.0      11.0
# 58296  2017-06-21   Darwin     21.2     32.6       0.0          7.6       8.6
# 58297  2017-06-22   Darwin     20.7     32.8       0.0          5.6      11.0
# 58298  2017-06-23   Darwin     19.5     31.8       0.0          6.2      10.6
# 58299  2017-06-24   Darwin     20.2     31.7       0.0          5.6      10.7
#
#       WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0             SSW           48.0        ENE  ...        20.0         13.0
# 1               S           37.0        SSE  ...        30.0          8.0
# 2             NNE           46.0        NNE  ...        42.0         22.0
# 3             WNW           31.0        WNW  ...        37.0         22.0
# 4             WNW           35.0         NW  ...        19.0         15.0
# ...           ...            ...        ...  ...         ...          ...
# 58295         ENE           35.0         SE  ...        63.0         32.0
# 58296           E           37.0         SE  ...        56.0         28.0
# 58297           E           33.0          E  ...        46.0         23.0
# 58298         ESE           26.0         SE  ...        62.0         58.0
# 58299         ENE           30.0        ENE  ...        73.0         32.0
#
#        Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0           1006.3       1004.4       2.0       5.0     26.6     33.4
# 1           1012.9       1012.1       1.0       1.0     20.3     27.0
# 2           1012.3       1009.2       1.0       6.0     28.7     34.9
# 3           1012.7       1009.1       1.0       5.0     29.1     35.6
# 4           1010.7       1007.4       1.0       6.0     33.6     37.6
# ...            ...          ...       ...       ...      ...      ...
# 58295       1013.9       1010.5       0.0       1.0     24.5     32.3
# 58296       1014.6       1011.2       7.0       0.0     24.8     32.0
# 58297       1015.3       1011.8       0.0       0.0     24.8     32.1
# 58298       1014.9       1010.7       1.0       1.0     24.8     29.2
# 58299       1013.9       1009.7       6.0       5.0     25.4     31.0
#
#        RainToday  RainTomorrow
# 0             No            No
# 1             No            No
# 2             No            No
# 3             No            No
# 4             No            No
# ...          ...           ...
# 58295         No            No
# 58296         No            No
# 58297         No            No
# 58298         No            No
# 58299         No            No
#
# [58300 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df1=df.drop(['Date','Location','WindGustDir','WindDir9am','WindDir3pm','RainToday'],axis=1)
df1
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0         17.9     35.2       0.0         12.0      12.3           48.0
# 1         18.4     28.9       0.0         14.8      13.0           37.0
# 2         19.4     37.6       0.0         10.8      10.6           46.0
# 3         21.9     38.4       0.0         11.4      12.2           31.0
# 4         24.2     41.0       0.0         11.2       8.4           35.0
# ...        ...      ...       ...          ...       ...            ...
# 58295     19.3     33.4       0.0          6.0      11.0           35.0
# 58296     21.2     32.6       0.0          7.6       8.6           37.0
# 58297     20.7     32.8       0.0          5.6      11.0           33.0
# 58298     19.5     31.8       0.0          6.2      10.6           26.0
# 58299     20.2     31.7       0.0          5.6      10.7           30.0
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               6.0          20.0         20.0         13.0       1006.3
# 1              19.0          19.0         30.0          8.0       1012.9
# 2              30.0          15.0         42.0         22.0       1012.3
# 3               6.0           6.0         37.0         22.0       1012.7
# 4              17.0          13.0         19.0         15.0       1010.7
# ...             ...           ...          ...          ...          ...
# 58295           9.0          20.0         63.0         32.0       1013.9
# 58296          13.0          11.0         56.0         28.0       1014.6
# 58297          17.0          11.0         46.0         23.0       1015.3
# 58298           9.0          17.0         62.0         58.0       1014.9
# 58299          15.0           7.0         73.0         32.0       1013.9
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainTomorrow
# 0           1004.4       2.0       5.0     26.6     33.4           No
# 1           1012.1       1.0       1.0     20.3     27.0           No
# 2           1009.2       1.0       6.0     28.7     34.9           No
# 3           1009.1       1.0       5.0     29.1     35.6           No
# 4           1007.4       1.0       6.0     33.6     37.6           No
# ...            ...       ...       ...      ...      ...          ...
# 58295       1010.5       0.0       1.0     24.5     32.3           No
# 58296       1011.2       7.0       0.0     24.8     32.0           No
# 58297       1011.8       0.0       0.0     24.8     32.1           No
# 58298       1010.7       1.0       1.0     24.8     29.2           No
# 58299       1009.7       6.0       5.0     25.4     31.0           No
#
# [58300 rows x 17 columns]

# %%
x=df1.iloc[:,:-1]
x
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0         17.9     35.2       0.0         12.0      12.3           48.0
# 1         18.4     28.9       0.0         14.8      13.0           37.0
# 2         19.4     37.6       0.0         10.8      10.6           46.0
# 3         21.9     38.4       0.0         11.4      12.2           31.0
# 4         24.2     41.0       0.0         11.2       8.4           35.0
# ...        ...      ...       ...          ...       ...            ...
# 58295     19.3     33.4       0.0          6.0      11.0           35.0
# 58296     21.2     32.6       0.0          7.6       8.6           37.0
# 58297     20.7     32.8       0.0          5.6      11.0           33.0
# 58298     19.5     31.8       0.0          6.2      10.6           26.0
# 58299     20.2     31.7       0.0          5.6      10.7           30.0
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               6.0          20.0         20.0         13.0       1006.3
# 1              19.0          19.0         30.0          8.0       1012.9
# 2              30.0          15.0         42.0         22.0       1012.3
# 3               6.0           6.0         37.0         22.0       1012.7
# 4              17.0          13.0         19.0         15.0       1010.7
# ...             ...           ...          ...          ...          ...
# 58295           9.0          20.0         63.0         32.0       1013.9
# 58296          13.0          11.0         56.0         28.0       1014.6
# 58297          17.0          11.0         46.0         23.0       1015.3
# 58298           9.0          17.0         62.0         58.0       1014.9
# 58299          15.0           7.0         73.0         32.0       1013.9
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm
# 0           1004.4       2.0       5.0     26.6     33.4
# 1           1012.1       1.0       1.0     20.3     27.0
# 2           1009.2       1.0       6.0     28.7     34.9
# 3           1009.1       1.0       5.0     29.1     35.6
# 4           1007.4       1.0       6.0     33.6     37.6
# ...            ...       ...       ...      ...      ...
# 58295       1010.5       0.0       1.0     24.5     32.3
# 58296       1011.2       7.0       0.0     24.8     32.0
# 58297       1011.8       0.0       0.0     24.8     32.1
# 58298       1010.7       1.0       1.0     24.8     29.2
# 58299       1009.7       6.0       5.0     25.4     31.0
#
# [58300 rows x 16 columns]

# %%
y=df1.iloc[:,-1]
y
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#          ..
# 58295    No
# 58296    No
# 58297    No
# 58298    No
# 58299    No
# Name: RainTomorrow, Length: 58300, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=.30,random_state=42)
x_train
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 36299     24.4     33.0       0.0          8.8      11.9           37.0
# 44601     18.4     36.3       0.0          4.0      12.5           63.0
# 1457      13.4     24.0       0.0          5.8      12.0           46.0
# 56872     22.1     31.9       0.0          8.0       9.8           44.0
# 48827     14.7     29.4       0.0          9.2      12.2           35.0
# ...        ...      ...       ...          ...       ...            ...
# 54343      9.0     21.2       0.0          8.6       8.6           37.0
# 38158      9.6     23.0       0.0          5.4      13.2           41.0
# 860       20.8     23.0      34.2          4.2       0.0           28.0
# 15795     12.5     20.9       0.0          6.0       0.7           33.0
# 56422     23.4     32.6      13.0          8.4       5.3           61.0
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 36299          17.0          28.0         67.0         66.0       1006.0
# 44601          15.0          17.0         35.0         16.0       1017.6
# 1457           20.0          31.0         62.0         60.0       1025.0
# 56872          17.0          20.0         56.0         32.0       1010.7
# 48827          11.0          17.0         44.0         35.0       1015.7
# ...             ...           ...          ...          ...          ...
# 54343          20.0          24.0         47.0         29.0       1022.1
# 38158          28.0          28.0         64.0         55.0       1016.7
# 860            13.0          11.0         95.0         96.0       1020.3
# 15795           6.0          11.0         90.0         87.0       1018.4
# 56422           7.0          11.0         96.0         60.0       1008.1
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm
# 36299       1004.1       2.0       1.0     29.5     30.9
# 44601       1013.0       1.0       0.0     24.0     35.1
# 1457        1022.6       2.0       2.0     21.5     22.9
# 56872       1007.7       6.0       7.0     25.2     30.9
# 48827       1010.7       1.0       7.0     22.3     27.4
# ...            ...       ...       ...      ...      ...
# 54343       1018.5       7.0       4.0     14.3     20.2
# 38158       1014.7       3.0       0.0     17.1     22.0
# 860         1019.8       8.0       8.0     22.2     21.1
# 15795       1018.1       7.0       8.0     17.0     20.5
# 56422       1004.3       8.0       7.0     24.4     31.1
#
# [40810 rows x 16 columns]

# %%
y_train
# Out:
# 36299     No
# 44601     No
# 1457      No
# 56872     No
# 48827     No
#         ...
# 54343     No
# 38158     No
# 860      Yes
# 15795    Yes
# 56422     No
# Name: RainTomorrow, Length: 40810, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
scaler=StandardScaler()
scaler1=MinMaxScaler()
scaler.fit(x_train)
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)
x_test
# Out:
# array([[ 1.25588929,  0.72191602, -0.28181741, ..., -0.4919823 ,
#          1.29396434,  0.6915358 ],
#        [-0.46158132,  0.08556679, -0.28181741, ..., -0.4919823 ,
#         -0.55393983,  0.13224893],
#        [-0.31977182, -0.75325719, -0.28181741, ..., -0.86773647,
#         -0.41534701, -0.67724521],
#        ...,
#        [ 0.26322279, -0.37723264,  2.62081002, ...,  0.25952603,
#         -0.10736299, -0.2062668 ],
#        [-0.82398337, -0.5797074 , -0.25859639, ..., -0.86773647,
#         -1.26230309, -0.57421868],
#        [ 0.81470418,  2.11031433, -0.28181741, ...,  1.01103437,
#          1.52495236,  2.14862525]])

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=5)
from sklearn.naive_bayes import GaussianNB
n_model=GaussianNB()
from sklearn.svm import SVC
s_model=SVC()

# %%
lst=[model,n_model,s_model]
for i in lst:
  i.fit(x_train,y_train)
  y_pred=model.predict(x_test)
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'Yes', 'No', 'No'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay
result1=confusion_matrix(y_test,y_pred)
result1
# Out:
# array([[12667,   937],
#        [ 1790,  2096]])

# %%
cm=['No','Yes']
cmd=ConfusionMatrixDisplay(result1,display_labels=cm)
cmd.plot()

# %%
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.8440823327615781

# %%
y_pred=n_model.predict(x_test)
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'Yes', 'No', 'No'], dtype='<U3')

# %%
result2=confusion_matrix(y_test,y_pred)
result2
# Out:
# array([[11456,  2148],
#        [ 1272,  2614]])

# %%
cm=['No','Yes']
cmd=ConfusionMatrixDisplay(result2,display_labels=cm)
cmd.plot()

# %%
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.8044596912521441

# %%
y_pred=s_model.predict(x_test)
y_pred
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
result3=confusion_matrix(y_test,y_pred)
result3
# Out:
# array([[13050,   554],
#        [ 1887,  1999]])

# %%
cm=['No','Yes']
cmd=ConfusionMatrixDisplay(result3,display_labels=cm)
cmd.plot()

# %%
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.8604345340194397

# %%
for i in lst:
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  score=accuracy_score(y_test,y_pred)
  print("accuracy :",score)
# Out:
# accuracy : 0.8440823327615781
# accuracy : 0.8044596912521441
# accuracy : 0.8604345340194397
